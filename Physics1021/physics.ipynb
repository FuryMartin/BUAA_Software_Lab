# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline

# %%
x = np.array([-1,0,5,10,15,20,25,30,35,40,45,50])
y_1 = np.array([0.6,1.6,9.8,14.1,19.5,23.2,25.8,28.2,30.1,31.7,33.0,33.9])
y_2 = np.array([0.3,0.8,3.5,5.5,7.2,8.6,9.9,10.7,11.2,11.6,12.1,12.5])
y_3 = np.array([0.01,0.04,1.10,1.51,1.96,2.20,2.36,2.50,2.63,2.67,2.73,2.77])

# %%
def get_curve(x,y):
    f1 = np.polyfit(x, y, 2)
    p1 = np.poly1d(f1)
    return p1(x)  # 拟合y值

# %%
def draw_graph_1(x,y_1,y_2,y_3):
    #获取当前的坐标轴, gca = get current axis\
    plt.figure(figsize=(8, 6), dpi=200)

    ax = plt.gca()

    plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
    plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
    # 设置标题，也可用plt.title()设置
    ax.set_title('同一光强，不同频率伏安特性图\n\n$L=400nm,\phi=4mm$', fontsize=15, loc='center')

    # 设置右边框和上边框，隐藏
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')

    # 设置x坐标轴为下边框
    ax.xaxis.set_ticks_position('bottom')
    # 设置y坐标轴为左边框
    ax.yaxis.set_ticks_position('left')

    # 设置x轴, y轴在(0, 0)的位置
    ax.spines['bottom'].set_position(('data', 0))
    ax.spines['left'].set_position(('data', 0))

    # ax.set_xticks与plt.xticks功能一样，都是自行定义x坐标轴的刻度；y轴同理。在这里使用避免原点出现两个同样的0
    ax.set_xticks([i for i in range(-5,x.max()+10,5)])
    ax.set_yticks([i for i in range(0,45,5)])

    plt.plot(x, get_curve(x, y_1), label='365.0nm')
    plt.plot(x, get_curve(x, y_2), label='404.7nm')
    plt.plot(x, get_curve(x, y_3), label='546.1nm')

    plt.scatter(x, y_1, marker='o')
    plt.scatter(x, y_2, marker='o')
    plt.scatter(x, y_3, marker='o')

    plt.xlim(-5, x.max()+5)
    plt.ylim(0, 55)
    plt.legend(loc='upper right')
    plt.xlabel('$U/V$', fontsize=10, loc='right')
    plt.ylabel('$I(x10^{-10})$A', fontsize=10, loc='top')
    #plt.savefig('output_1.jpg')

# %%
draw_graph_1(x,y_1,y_2,y_3)

# %%
def draw_graph_2(x,y_1,y_2,y_3):
    #获取当前的坐标轴, gca = get current axis\
    plt.figure(figsize=(8, 7), dpi=200)

    ax = plt.gca()

    plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
    plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
    # 设置标题，也可用plt.title()设置
    ax.set_title('同一频率，不同光强伏安特性图\n\n$\lambda=435.8nm,L=400mm$',
                 fontsize=15, loc='center')

    # 设置右边框和上边框，隐藏
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')

    # 设置x坐标轴为下边框
    ax.xaxis.set_ticks_position('bottom')
    # 设置y坐标轴为左边框
    ax.yaxis.set_ticks_position('left')

    # 设置x轴, y轴在(0, 0)的位置
    ax.spines['bottom'].set_position(('data', 0))
    ax.spines['left'].set_position(('data', 0))

    # ax.set_xticks与plt.xticks功能一样，都是自行定义x坐标轴的刻度；y轴同理。在这里使用避免原点出现两个同样的0
    ax.set_xticks([i for i in range(-5, 60, 5)])
    ax.set_yticks([i for i in range(0, 120, 5)])

    plt.plot(x, get_curve(x, y_1), label='2mm')
    plt.plot(x, get_curve(x, y_2), label='4mm')
    plt.plot(x, get_curve(x, y_3), label='8mm')

    plt.scatter(x, y_1, marker='o')
    plt.scatter(x, y_2, marker='o')
    plt.scatter(x, y_3, marker='o')
    plt.xlim(-5, x.max()+5)
    plt.ylim(0, 120)
    plt.legend(loc='center right')
    plt.xlabel('$U/V$', fontsize=10, loc='right')
    plt.ylabel('$I(x10^{-10})$A', fontsize=10, loc='top')
    #plt.savefig('output_2.jpg')

# %%
y_1 = np.array([0.1,0.4,2.0,3.1,4.1,4.7,5.3,5.6,6.2,6.4,6.6,6.5])
y_2 = np.array([0.2,1.1,6.8,10.6,14.1,16.5,18.5,19.8,21.2,21.6,22.3,23.0])
y_3 = np.array([0.4,4.3,27.9,44.6,62.1,66.7,79.0,99.3,97.3,105.7,110.7,112.4])

draw_graph_2(x,y_1,y_2,y_3)

# %%
def draw_graph_3(x,y):
    #获取当前的坐标轴, gca = get current axis\
    plt.figure(figsize=(8, 7), dpi=200)

    ax = plt.gca()

    plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
    plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
    # 设置标题，也可用plt.title()设置
    ax.set_title('距离-光强图\n\n$U_{AK}=50V,\phi=4mm$',fontsize=15, loc='center')

    # 设置右边框和上边框，隐藏
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')

    # 设置x坐标轴为下边框
    ax.xaxis.set_ticks_position('bottom')
    # 设置y坐标轴为左边框
    ax.yaxis.set_ticks_position('left')

    # 设置x轴, y轴在(0, 0)的位置
    ax.spines['bottom'].set_position(('data', 0))
    ax.spines['left'].set_position(('data',290))

    # ax.set_xticks与plt.xticks功能一样，都是自行定义x坐标轴的刻度；y轴同理。在这里使用避免原点出现两个同样的0
    ax.set_xticks([i for i in range(x.min()-10, x.max()+20, 10)])
    ax.set_yticks([i for i in range(0, 60, 5)])

    plt.plot(x, get_curve(x, y))

    plt.scatter(x, y, marker='o')

    plt.xlim(x.min()-10, x.max()+5)
    plt.ylim(0, 60)
    plt.xlabel('$L/mm$', fontsize=10, loc='right')
    plt.ylabel('$I(x10^{-10})$A', fontsize=10, loc='top')
    #plt.savefig('output_3.jpg')

# %%
x = np.array([i for i in range(300,410,10)])
y = np.array([52.3,48.0,42.6,41.1,36.6,33.3,30.9,29.2,26.3,25.0,23.4])
draw_graph_3(x,y)
